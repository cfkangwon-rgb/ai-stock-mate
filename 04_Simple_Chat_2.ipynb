# %%
from langchain_openai import ChatOpenAI
from langchain_teddynote import logging
from langchain_teddynote.messages import stream_response

from dotenv import load_dotenv
import os

# API KEY 정보로드
load_dotenv()


# 프로젝트 이름을 입력합니다.
logging.langsmith(os.environ["STUDENT_NAME"] + "-" + "Simple_Chat")

# ChatOpenAI 객체를 생성합니다.
gpt = ChatOpenAI(
    temperature=1,  # 창의성 (0.0 ~ 2.0)
    model_name="gpt-4.1-mini",  # 모델명,
)

# %%
# 질의내용
question = "삼성전자 주식을 매수 해도 되나요?"

# 스트리밍 출력을 위하여 invoke() 대신 stream()을 사용합니다.
answer = gpt.stream(question)

# 답변 출력
stream_response(answer)

# %%
from langchain_openai import ChatOpenAI
from langchain_teddynote import logging
from langchain_teddynote.messages import stream_response
from langchain_core.chat_history import InMemoryChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory

from dotenv import load_dotenv
import os

# API KEY 정보로드
load_dotenv()

# 프로젝트 이름을 입력합니다.
logging.langsmith(os.environ["STUDENT_NAME"] + "-" + "Simple_Chat")

# ChatOpenAI 객체를 생성합니다.
gpt = ChatOpenAI(
    temperature=1,  # 창의성 (0.0 ~ 2.0)
    model_name="gpt-4o-mini",  # 올바른 모델명으로 수정
)
# Out:
# c:\Users\admin\AppData\Local\pypoetry\Cache\virtualenvs\langchain-kr--9JOM957-py3.11\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.7.0) or chardet (7.4.3)/charset_normalizer (3.4.7) doesn't match a supported version!
#   warnings.warn(
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# kim-kang-won-Simple_Chat

# %%
# 1. 세션별 대화 이력을 저장할 딕셔너리 생성
store = {}

def get_session_history(session_id: str) -> InMemoryChatMessageHistory:
    """세션 ID에 해당하는 대화 이력을 반환하거나 새로 생성합니다."""
    if session_id not in store:
        store[session_id] = InMemoryChatMessageHistory()
    return store[session_id]

# 2. GPT 모델에 대화 이력 관리 기능(RunnableWithMessageHistory)을 래핑합니다.
with_message_history = RunnableWithMessageHistory(
    gpt,
    get_session_history,
)

# %%
# 3. 세션 설정 (동일한 session_id를 사용하면 이전 대화를 기억합니다)
config = {"configurable": {"session_id": "user_session_1"}}

# --- 첫 번째 질문 (주식 매수 문의) ---
question1 = "삼성전자 주식을 매수 해도 되나요?"
print(f"[질문 1] {question1}\n[답변 1] ", end="")

# 이력이 포함된 객체로 스트리밍 실행
answer1 = with_message_history.stream(question1, config=config)
stream_response(answer1)
print("\n" + "="*50 + "\n")
# Out:
# [질문 1] 삼성전자 주식을 매수 해도 되나요?
# [답변 1] 삼성전자 주식 매수 여부는 여러 요소를 고려해야 합니다. 투자 결정을 내리기 전에 다음과 같은 사항을 고려해보세요:
#
# 1. **재무 상태**: 삼성전자의 최근 재무제표와 수익성을 분석해보세요. 매출, 순이익, 부채비율 등을 살펴보는 것이 좋습니다.
#
# 2. **글로벌 경제 상황**: 삼성전자는 글로벌 시장에서 활동하는 기업이기 때문에, 글로벌 경제 전망이나 특정 산업(예: 반도체, 전자제품)의 경향을 고려해야 합니다.
#
# 3. **주가 동향**: 주가의 변동성과 과거 실적을 분석해 보세요. 기술적 분석을 통해 매수 시점을 판단하는 것도 도움이 됩니다.
#
# 4. **뉴스 및 이슈**: 삼성전자가 직면한 정책 변화, 경쟁사 동향, 기술 혁신 등 뉴스와 이슈를 주의 깊게 살펴보세요.
#
# 5. **개인 투자 전략**: 주식 투자에 대한 본인의 목표와 리스크 감수 능력을 고려하여 결정하세요. 장기 투자인지 단기 투자인지에 따라 전략이 달라질 수 있습니다.
#
# 투자는 항상 리스크를 수반하므로, 필요하다면 금융 전문가와 상담하는 것이 좋습니다.
# ==================================================

# %%
# --- 두 번째 질문 (이전 대화 기억 확인) ---
question2 = "내가 방금 전에 어떤 기업에 대해 물어봤었지?"
print(f"[질문 2] {question2}\n[답변 2] ", end="")

# 동일한 config(session_id)를 전달하여 이전 문맥을 기억하게 합니다.
answer2 = with_message_history.stream(question2, config=config)
stream_response(answer2)
print()
# Out:
# [질문 2] 내가 방금 전에 어떤 기업에 대해 물어봤었지?
# [답변 2] 안녕하세요! 당신이 방금 전에 삼성전자 주식 매수 가능성에 대해 물어보셨습니다. 삼성전자와 관련된 질문이었죠. 추가로 궁금한 사항이 있으면 알려주세요!
